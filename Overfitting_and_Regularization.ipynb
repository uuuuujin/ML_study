# %% [markdown]
# ## Bias - Variance tradeoff
# - High bias : 원래 모델에 많이 떨어짐. 잘못된 데이터만 계속 학습함 --> 잘못된 weight만 updqte
# - Higd variance : 모든 데이터에 민감하게 학습. error를 고려하지 않음. --> 모든 weight가 updqte
#
# ## Overfitting
# - 학습데이터 과다 최적화 --> 새로운 데이터의 예측 감소
#
# ### Overcoming overfitting
# - 더 많은 데이터를 활용
# - feature의 개수를 줄임
# - 적절히 parameter를 선정
# - Regularization

# %% [markdown]
# ## L2 regularization
# - 기존 cost function L2(norm) penalty term을 추가
# - norm : 벡터의 길이 혹은 크기를 측정하는 방법
# - L2 : Euclidean distance (원점에서 벡터 좌표까지의 거리)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## L1 regularization
# - 기존 cost function L1(norm) penalty term을 추가
# - L1 : manhattan distance (원점에서 벡터 좌표까지의 거리)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
